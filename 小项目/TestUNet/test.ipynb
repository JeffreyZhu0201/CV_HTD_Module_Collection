# %% [markdown]
# # 数据加载

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
data = sio.loadmat("./WDCCR/airport.mat")
# print(data['data'])
# 显示 'map' 变量为图片
plt.imshow(data['data'][0], cmap='gray')
plt.title('Map')
plt.axis('off')
plt.show()
for key, value in data.items():
    print(f"{key}: type={type(value)}, shape={getattr(value, 'shape', None)}")
# Out:
# __header__: type=<class 'bytes'>, shape=None
# __version__: type=<class 'str'>, shape=None
# __globals__: type=<class 'list'>, shape=None
# S: type=<class 'numpy.ndarray'>, shape=(205, 5)
# Slocation: type=<class 'numpy.ndarray'>, shape=(5, 2)
# XY: type=<class 'numpy.ndarray'>, shape=(144, 2)
# data: type=<class 'numpy.ndarray'>, shape=(100, 100, 205)
# map: type=<class 'numpy.ndarray'>, shape=(100, 100)
